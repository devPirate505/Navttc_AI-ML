# %%
from PIL import Image
from matplotlib import pyplot as plt

# %%
image = Image.open("./1.jpg")

# %%
plt.imshow(image)

# %%
image = image.resize((605,870))

# %%
image.save("output.jpg")

# %%
image = image.convert("L")

# %%
image
# Out:
# <PIL.Image.Image image mode=L size=605x870>

# %%
from PIL import ImageOps
colorized_image = ImageOps.colorize(image, black="blue", white="red")

# %%
colorized_image
# Out:
# <PIL.Image.Image image mode=RGB size=605x870>
